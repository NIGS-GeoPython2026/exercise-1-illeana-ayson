# %%
ice_cream_rating=7
sleeping_rating=9

# %%
first_name = input('Please enter your first name: ')
last_name = input('Please enter your last name: ')
my_name = first_name,last_name
# Out:
# Please enter your first name:  Illeana
# Please enter your last name:  Ayson

# %%
happiness_rating = (int(ice_cream_rating) + int(sleeping_rating))/2

# %%
print('ice_cream_rating data type: ', type(ice_cream_rating),
      '\nfirst_name data type: ', type(first_name),
      '\nhappiness_rating data type: ', type(happiness_rating))
# Out:
# ice_cream_rating data type:  <class 'int'>
# first_name data type:  <class 'str'>
# happiness_rating data type:  <class 'float'>

# %% [markdown]
# Yes, the data types make sense for the first two. The value stored in the ice_cream_rating is an integer. Since the first_name variable uses the input() function, it is stored as a string. As for the last variable, I thought the type() function would return 'int' since the average is a whole number, but it does make sense for the division operator to always return a float.
